# %%
from src.physics.dynamics import HSRSolver
from src.physics.simulation import MonteCarloRunner
from tqdm import tqdm

# Setup
solver = HSRSolver()
runner = MonteCarloRunner(solver)

ns_list, r_list = [], []

for _ in tqdm(range(125000)):
    # ... generate y_initial using your distribution logic ...
    
    ns, r = runner.run_single(y_initial, n_obs=55)
    
    if ns is not None:
        ns_list.append(ns)
        r_list.append(r)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.physics.dynamics import HSRSolver
#       2 from src.physics.simulation import MonteCarloRunner
#       3 from tqdm import tqdm
#
# ModuleNotFoundError: No module named 'src'
